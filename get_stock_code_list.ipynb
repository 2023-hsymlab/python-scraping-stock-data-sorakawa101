# %% [markdown]
# #### 【参考】
# [Pythonで株の銘柄コード一覧を取得する方法](https://book-read-yoshi.hatenablog.com/entry/get_stock_codelist)

# %%
import pandas as pd
import requests


def get_stock_code_list_from_exel():
    url = "https://www.jpx.co.jp/markets/statistics-equities/misc/tvdivq0000001vg2-att/data_j.xls"
    r = requests.get(url)

    with open('data_j.xls', 'wb') as output:
        output.write(r.content)

    stocklist = pd.read_excel("./data_j.xls")
    stocklist.loc[stocklist["市場・商品区分"] == "市場第一部（内国株）",
                ["コード", "銘柄名", "33業種コード", "33業種区分", "規模コード", "規模区分"]
                ]
    return stocklist

# %%
df = get_stock_code_list_from_exel()

# %%
df
# Out:
#             日付   コード                                   銘柄名       市場・商品区分  \
# 0     20230428  1301                                    極洋    プライム（内国株式）
# 1     20230428  1305                ｉＦｒｅｅＥＴＦ　ＴＯＰＩＸ（年１回決算型）       ETF・ETN
# 2     20230428  1306               ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連動型上場投信       ETF・ETN
# 3     20230428  1308                     上場インデックスファンドＴＯＰＩＸ       ETF・ETN
# 4     20230428  1309  ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡＭＣ・中国株式・上証５０連動型上場投信       ETF・ETN
# ...        ...   ...                                   ...           ...
# 4265  20230428  9993                                  ヤマザワ  スタンダード（内国株式）
# 4266  20230428  9994                                   やまや  スタンダード（内国株式）
# 4267  20230428  9995                                 グローセル    プライム（内国株式）
# 4268  20230428  9996                                 サトー商会  スタンダード（内国株式）
# 4269  20230428  9997                                  ベルーナ    プライム（内国株式）
#
#      33業種コード  33業種区分 17業種コード  17業種区分 規模コード           規模区分
# ...

# %%
import os

# .env ファイルをロードして環境変数へ反映
from dotenv import load_dotenv
load_dotenv()



host='localhost',
user='root',
password=os.getenv('MYSQL_PASSWORD'),
database='scraping_stock_data',

# %%
# DBに接続
connection = pymysql.connect(host='localhost',
                             user='root',
                             password=os.getenv('MYSQL_PASSWORD'),
                             database='db_sample',
                             # cursorclassを指定することでSelect結果をtupleではなくdictionaryで受け取れる
                             cursorclass=pymysql.cursors.DictCursor)

# %%
import pymysql.cursors
from sqlalchemy import create_engine

with connection:
    #engine = create_engine('mysql://<user>:<password>@<host>/<database>?charset=utf8')
    engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}', echo=False)

    #df.to_sql(<table_name>,con=engine, if_exists='append', index=False)
    df.to_sql(con=engine, name='stock_code_list', if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pymysql/connections.py in connect(self, sock)
#     615                         try:
# --> 616                             sock = socket.create_connection(
#     617                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/socket.py in create_connection(address, timeout, source_address)
#     821     err = None
# --> 822     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     823         af, socktype, proto, canonname, sa = res
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     952     addrlist = []
# --> 953     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     954         af, socktype, proto, canonname, sa = res
# ...
